# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style='whitegrid')
import missingno as msno

# %% [markdown]
# We first needed to import the python packages we needed (most of which we need to use later)

# %% [markdown]
# We will now import the data from GitHub to use in our analysis

# %%
df_seattle = pd.read_csv('https://github.com/nitschels/Seattle-Weather/raw/main/seattle_rain.csv')
df_ny = pd.read_csv('https://github.com/nitschels/Seattle-Weather/raw/main/ny_rain.csv')

# Need to change these to my own links

# %% [markdown]
# Since the "DATE" column is not in a datetime data type in the csv file, we will use pandas to check what type it is, and then change it to datetime.

# %%
df_seattle.dtypes
# Out:
# STATION       object
# NAME          object
# LATITUDE     float64
# LONGITUDE    float64
# ELEVATION    float64
# DATE          object
# DAPR         float64
# MDPR         float64
# PRCP         float64
# SNOW         float64
# SNWD         float64
# DASF         float64
# MDSF         float64
# dtype: object

# %%
df_seattle["DATE"] = pd.to_datetime(df_seattle["DATE"])
df_ny["DATE"] = pd.to_datetime(df_ny["DATE"])

# %%
df_seattle.dtypes
# Out:
# STATION              object
# NAME                 object
# LATITUDE            float64
# LONGITUDE           float64
# ELEVATION           float64
# DATE         datetime64[ns]
# DAPR                float64
# MDPR                float64
# PRCP                float64
# SNOW                float64
# SNWD                float64
# DASF                float64
# MDSF                float64
# dtype: object

# %% [markdown]
# Now that the "DATE" column is datetime as desired, we can move on to other things

# %% [markdown]
# We will check the columns for both Seattle and New York for what columns we can remove.

# %%
df_seattle
# Out:
#           STATION                           NAME   LATITUDE   LONGITUDE  \
# 0     US1WAKG0199           SEATTLE 4.5 N, WA US  47.686424 -122.362209
# 1     US1WAKG0255         SEATTLE 6.5 SSW, WA US  47.530849 -122.382541
# 2     US1WAKG0243         SEATTLE 3.9 SSW, WA US  47.567666 -122.372386
# 3     US1WAKG0145           SEATTLE 4.2 N, WA US  47.681873 -122.365539
# 4     US1WAKG0192           SEATTLE 5.6 N, WA US  47.702387 -122.351663
# ...           ...                            ...        ...         ...
# 6998  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.444670 -122.314420
# 6999  US1WAKG0145           SEATTLE 4.2 N, WA US  47.681873 -122.365539
# 7000  US1WAKG0229         SEATTLE 5.5 NNE, WA US  47.696532 -122.312907
# 7001  US1WAKG0225         SEATTLE 2.1 ESE, WA US  47.611700 -122.308500
# 7002  USW00024233  SEATTLE TACOMA AIRPORT, WA US  47.444670 -122.314420
#
#       ELEVATION       DATE  DAPR  MDPR  PRCP  SNOW  SNWD  DASF  MDSF
# 0          82.9 2020-01-01   NaN   NaN  0.19   NaN   NaN   NaN   NaN
# 1         135.0 2020-01-01   NaN   NaN  0.23   NaN   NaN   NaN   NaN
# 2          48.2 2020-01-01   NaN   NaN  0.19   NaN   NaN   NaN   NaN
# 3          74.1 2020-01-01   NaN   NaN  0.13   NaN   NaN   NaN   NaN
# 4         112.5 2020-01-01   NaN   NaN  0.22   NaN   NaN   NaN   NaN
# ...         ...        ...   ...   ...   ...   ...   ...   ...   ...
# 6998      112.5 2023-12-30   NaN   NaN  0.10   0.0   0.0   NaN   NaN
# 6999       74.1 2023-12-31   NaN   NaN  0.06   NaN   NaN   NaN   NaN
# 7000      135.6 2023-12-31   NaN   NaN  0.06   NaN   NaN   NaN   NaN
# 7001      121.3 2023-12-31   NaN   NaN  0.08   NaN   NaN   NaN   NaN
# 7002      112.5 2023-12-31   NaN   NaN  0.00   0.0   0.0   NaN   NaN
#
# [7003 rows x 13 columns]

# %%
df_ny
# Out:
#            STATION                                 NAME   LATITUDE  LONGITUDE  \
# 0      USW00094728          NY CITY CENTRAL PARK, NY US  40.778980 -73.969250
# 1      US1NYWC0018                 ARMONK 0.3 SE, NY US  41.129960 -73.708161
# 2      US1NYNS0034               WANTAGH 0.3 ESE, NY US  40.666824 -73.505371
# 3      USW00054787  FARMINGDALE REPUBLIC AIRPORT, NY US  40.734430 -73.416370
# 4      US1NYNS0042             ALBERTSON 0.2 SSE, NY US  40.769131 -73.647484
# ...            ...                                  ...        ...        ...
# 17460  US1NYSF0158            LINDENHURST 1.0 NE, NY US  40.695085 -73.358045
# 17461  US1NYNS0042             ALBERTSON 0.2 SSE, NY US  40.769131 -73.647484
# 17462  USW00094728          NY CITY CENTRAL PARK, NY US  40.778980 -73.969250
# 17463  US1NYSF0089            AMITYVILLE 0.1 WSW, NY US  40.668899 -73.418342
# 17464  US1NYWC0018                 ARMONK 0.3 SE, NY US  41.129960 -73.708161
#
#        ELEVATION       DATE  DAPR  MDPR  PRCP  SNOW  SNWD  DASF  MDSF
# 0           42.7 2020-01-01   NaN   NaN  0.00   0.0   0.0   NaN   NaN
# 1          117.3 2020-01-01   NaN   NaN  0.06   0.0   0.0   NaN   NaN
# 2            4.3 2020-01-01   NaN   NaN  0.00   0.0   0.0   NaN   NaN
# 3           22.8 2020-01-01   NaN   NaN  0.00   NaN   NaN   NaN   NaN
# 4           43.3 2020-01-01   NaN   NaN  0.00   0.0   NaN   NaN   NaN
# ...          ...        ...   ...   ...   ...   ...   ...   ...   ...
# 17460        5.2 2023-12-31   NaN   NaN  0.00   0.0   NaN   NaN   NaN
# 17461       43.3 2023-12-31   NaN   NaN  0.00   0.0   NaN   NaN   NaN
# 17462       42.7 2023-12-31   NaN   NaN  0.00   0.0   0.0   NaN   NaN
# 17463        3.7 2023-12-31   NaN   NaN  0.00   0.0   NaN   NaN   NaN
# 17464      117.3 2023-12-31   NaN   NaN  0.00   0.0   0.0   NaN   NaN
#
# [17465 rows x 13 columns]

# %% [markdown]
# As we are looking through the data, we notice columns that either aren't very descriptive, or are useful for our exploration, so we will remove these columns.

# %%
bad_cols = ["ELEVATION", "DAPR", "MDPR", "SNOW", "SNWD", "DASF", "MDSF", "STATION", "NAME", "LATITUDE", "LONGITUDE"]
df_seattle = df_seattle.drop(columns=bad_cols)
df_ny = df_ny.drop(columns=bad_cols)

# %% [markdown]
# Once the columns are removed, we will continue with more data cleaning.

# %%
df_seattle.shape
# Out:
# (7003, 2)

# %%
df_ny.shape
# Out:
# (17465, 2)

# %% [markdown]
# We check how many rows are in each of the data sets and notice that New York has over 10000 more data point than Seattle. To get past this, we will take the average of precipitation across all the dates in our data set to get an idea of what the weather was like across the city on a given day.

# %%
df_seattle_avg = df_seattle.groupby(by="DATE", as_index=False)["PRCP"].mean()
df_ny_avg = df_ny.groupby(by="DATE", as_index=False)["PRCP"].mean()

# %%
df_seattle_avg
# Out:
#            DATE      PRCP
# 0    2020-01-01  0.162500
# 1    2020-01-02  0.181250
# 2    2020-01-03  0.267500
# 3    2020-01-04  0.172000
# 4    2020-01-05  0.168571
# ...         ...       ...
# 1456 2023-12-27  0.063333
# 1457 2023-12-28  0.240000
# 1458 2023-12-29  0.055000
# 1459 2023-12-30  0.042500
# 1460 2023-12-31  0.050000
#
# [1461 rows x 2 columns]

# %% [markdown]
# Since we are trying to compare the two, we will join the tables for the two cities in order to compare the two.

# %%
df_both = df_seattle_avg.merge(df_ny_avg, on = 'DATE', how = 'inner')
df_both
# Out:
#            DATE    PRCP_x    PRCP_y
# 0    2020-01-01  0.162500  0.013333
# 1    2020-01-02  0.181250  0.000000
# 2    2020-01-03  0.267500  0.134444
# 3    2020-01-04  0.172000  0.200000
# 4    2020-01-05  0.168571  0.040000
# ...         ...       ...       ...
# 1456 2023-12-27  0.063333  0.051538
# 1457 2023-12-28  0.240000  1.845000
# 1458 2023-12-29  0.055000  0.103571
# 1459 2023-12-30  0.042500  0.006429
# 1460 2023-12-31  0.050000  0.000714
#
# [1461 rows x 3 columns]

# %% [markdown]
# However, since we are comparing the values, it would be easier to visualize across the same column. Melting the data will do this for us.

# %%
df = pd.melt(df_both, id_vars = 'DATE', var_name = 'CITY', value_name = 'PRCP')

# %%
df
# Out:
#            DATE    CITY      PRCP
# 0    2020-01-01  PRCP_x  0.162500
# 1    2020-01-02  PRCP_x  0.181250
# 2    2020-01-03  PRCP_x  0.267500
# 3    2020-01-04  PRCP_x  0.172000
# 4    2020-01-05  PRCP_x  0.168571
# ...         ...     ...       ...
# 2917 2023-12-27  PRCP_y  0.051538
# 2918 2023-12-28  PRCP_y  1.845000
# 2919 2023-12-29  PRCP_y  0.103571
# 2920 2023-12-30  PRCP_y  0.006429
# 2921 2023-12-31  PRCP_y  0.000714
#
# [2922 rows x 3 columns]

# %% [markdown]
# When we look at this data frame, PRCP_x and PRCP_Y aren't very descriptive, so we will rename these as the cities that we are looking at.

# %%
df.loc[df['CITY']=='PRCP_x', 'CITY'] = 'SEA'
df.loc[df['CITY']=='PRCP_y', 'CITY'] = 'NYC'
df
# Out:
#            DATE CITY      PRCP
# 0    2020-01-01  SEA  0.162500
# 1    2020-01-02  SEA  0.181250
# 2    2020-01-03  SEA  0.267500
# 3    2020-01-04  SEA  0.172000
# 4    2020-01-05  SEA  0.168571
# ...         ...  ...       ...
# 2917 2023-12-27  NYC  0.051538
# 2918 2023-12-28  NYC  1.845000
# 2919 2023-12-29  NYC  0.103571
# 2920 2023-12-30  NYC  0.006429
# 2921 2023-12-31  NYC  0.000714
#
# [2922 rows x 3 columns]

# %% [markdown]
# We now would like to rename the column names to make them more readable and understandable.

# %%
mapping_dict = {'DATE':'date', 'CITY':'city', 'PRCP':'precipitation'}
df = df.rename(columns=mapping_dict)
df
# Out:
#            date city  precipitation
# 0    2020-01-01  SEA       0.162500
# 1    2020-01-02  SEA       0.181250
# 2    2020-01-03  SEA       0.267500
# 3    2020-01-04  SEA       0.172000
# 4    2020-01-05  SEA       0.168571
# ...         ...  ...            ...
# 2917 2023-12-27  NYC       0.051538
# 2918 2023-12-28  NYC       1.845000
# 2919 2023-12-29  NYC       0.103571
# 2920 2023-12-30  NYC       0.006429
# 2921 2023-12-31  NYC       0.000714
#
# [2922 rows x 3 columns]

# %% [markdown]
# Now that we have the cities labeled as desired, we can export the dataframe as a csv file using Pandas

# %%
df.to_csv('SEA_NY_WEATHER.csv')
